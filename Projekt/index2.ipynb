# %% [markdown]
# # PHP 2021

# %% [markdown]
# ## Projekt

# %%
! sudo docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
    
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";   

# %cd project

! composer install

! cp .env.example .env

! php artisan key:generate
    
! php artisan migrate:fresh
    
! php artisan db:seed
    
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/_data/dump.sql

import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

! vendor/bin/codecept run
# Out:
# 1e07e29379f6f09cb3f2aaecf3d268af3159c75b3658c191088b1bb815db75b0
# Done.
# /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Warning: The lock file is not up to date with the latest changes in composer.json. You may be getting outdated dependencies. It is recommended that you run `composer update` or `composer update <package name>`.
# Nothing to install, update or remove
# Package swiftmailer/swiftmailer is abandoned, you should avoid using it. Use symfony/mailer instead.
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
# Discovered Package: facade/ignition
# Discovered Package: fruitcake/laravel-cors
# Discovered Package: laravel/breeze
# Discovered Package: laravel/sail
# Discovered Package: laravel/sanctum
# Discovered Package: laravel/tinker
# Discovered Package: nesbot/carbon
# Discovered Package: nunomaduro/collision
# Discovered Package: spatie/laravel-markdown
# Package manifest generated successfully.
# 86 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# Application key set successfully.
# Dropped all tables successfully.
# Migration table created successfully.
# Migrating: 2014_10_12_000000_create_users_table
# Migrated:  2014_10_12_000000_create_users_table (49.52ms)
# Migrating: 2014_10_12_100000_create_password_resets_table
# Migrated:  2014_10_12_100000_create_password_resets_table (39.90ms)
# Migrating: 2019_08_19_000000_create_failed_jobs_table
# Migrated:  2019_08_19_000000_create_failed_jobs_table (37.45ms)
# Migrating: 2019_12_14_000001_create_personal_access_tokens_table
# Migrated:  2019_12_14_000001_create_personal_access_tokens_table (70.40ms)
# Migrating: 2022_01_09_132531_create_categories_table
# Migrated:  2022_01_09_132531_create_categories_table (24.01ms)
# Migrating: 2022_01_09_132734_create_fundraisers_table
# Migrated:  2022_01_09_132734_create_fundraisers_table (184.87ms)
# Migrating: 2022_01_09_132745_create_donations_table
# Migrated:  2022_01_09_132745_create_donations_table (178.35ms)
# Seeding: Database\Seeders\UserSeeder
# Seeded:  Database\Seeders\UserSeeder (365.08ms)
# Seeding: Database\Seeders\CategorySeeder
# Seeded:  Database\Seeders\CategorySeeder (28.48ms)
# Seeding: Database\Seeders\FundraiserSeeder
# Seeded:  Database\Seeders\FundraiserSeeder (16.44ms)
# Seeding: Database\Seeders\DonationSeeder
# Seeded:  Database\Seeders\DonationSeeder (3.48ms)
# Database seeding completed successfully.
# mysqldump: [Warning] Using a password on the command line interface can be insecure.
# Starting Laravel development server: http://127.0.0.1:8888
# Codeception PHP Testing Framework v4.1.28
# Powered by PHPUnit 9.5.11 by Sebastian Bergmann and contributors.
# [Mon Jan 17 18:05:08 2022] PHP 8.0.10 Development Server (http://127.0.0.1:8888) started
#
# Acceptance Tests (6) -----------------------------------------------------------
# - DonationsCept: Have donations page[Mon Jan 17 18:05:09 2022] 127.0.0.1:45124 Accepted
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45124 Closing
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45128 Accepted
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45128 Closing
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45134 Accepted
# ✖ DonationsCept: Have donations page (0.67s)
# - EmailVerificationCept: Verify email[Mon Jan 17 18:05:10 2022] 127.0.0.1:45134 Closing
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45140 Accepted
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45140 Closing
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45146 Accepted
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45146 Closing
# [Mon Jan 17 18:05:10 2022] 127.0.0.1:45150 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45150 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45156 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45156 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45162 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45162 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45168 Accepted
# ✔ EmailVerificationCept: Verify email (0.63s)
# - FundraisersCept: Have fundraisers page[Mon Jan 17 18:05:11 2022] 127.0.0.1:45168 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45174 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45174 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45180 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45180 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45186 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45186 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45192 Accepted
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45192 Closing
# [Mon Jan 17 18:05:11 2022] 127.0.0.1:45196 Accepted
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45196 Closing
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45202 Accepted
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45202 Closing
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45208 Accepted
# ✖ FundraisersCept: Have fundraisers page (0.51s)
# - LoginCept: Login with existing user[Mon Jan 17 18:05:12 2022] 127.0.0.1:45208 Closing
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45214 Accepted
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45214 Closing
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45220 Accepted
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45220 Closing
# ✔ LoginCept: Login with existing user (0.34s)
# - UserCept: Have users page[Mon Jan 17 18:05:12 2022] 127.0.0.1:45226 Accepted
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45226 Closing
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45230 Accepted
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45230 Closing
# [Mon Jan 17 18:05:12 2022] 127.0.0.1:45234 Accepted
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45234 Closing
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45240 Accepted
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45240 Closing
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45246 Accepted
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45246 Closing
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45252 Accepted
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45252 Closing
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45258 Accepted
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45258 Closing
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45262 Accepted
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45262 Closing
# [Mon Jan 17 18:05:13 2022] 127.0.0.1:45266 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45266 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45272 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45272 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45278 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45278 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45284 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45284 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45290 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45290 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45296 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45296 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45302 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45302 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45308 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45308 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45314 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45314 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45320 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45320 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45326 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45326 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45332 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45332 Closing
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45338 Accepted
# [Mon Jan 17 18:05:14 2022] 127.0.0.1:45338 Closing
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45344 Accepted
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45344 Closing
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45350 Accepted
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45350 Closing
# ✖ UserCept: Have users page (1.60s)
# - XMarkdownCept: Check x-markdown[Mon Jan 17 18:05:15 2022] 127.0.0.1:45356 Accepted
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45356 Closing
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45360 Accepted
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45360 Closing
# ✔ XMarkdownCept: Login with existing user (0.60s)
# --------------------------------------------------------------------------------
#
#
# Time: 00:07.567, Memory: 14.00 MB
#
# There were 3 failures:
#
# ---------
# 1) DonationsCept: Have donations page
#  Test  tests_codeception/acceptance/DonationsCept.php
#  Step  Click "Na schornisko dla kotków"
#  Fail  Link or Button by name or CSS or XPath element with 'Na schornisko dla kotków' was not found.
#
# Scenario Steps:
#
#  6. $I->click("Na schornisko dla kotków") at tests_codeception/acceptance/DonationsCept.php:15
#  5. $I->amOnPage("/fundraisers") at tests_codeception/acceptance/DonationsCept.php:13
#  4. $I->click("Log in") at tests_codeception/acceptance/DonationsCept.php:11
#  3. $I->fillField("password","secret") at tests_codeception/acceptance/DonationsCept.php:10
#  2. $I->fillField("email","john.doe@gmail.com") at tests_codeception/acceptance/DonationsCept.php:9
#  1. $I->amOnPage("/login") at tests_codeception/acceptance/DonationsCept.php:8
#
# Artifacts:
#
# Html: /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project/tests_codeception/_output/DonationsCept.fail.html
# Response: /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project/tests_codeception/_output/DonationsCept.fail.html
#
# ---------
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45364 Accepted
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45364 Closing
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45370 Accepted
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45370 Closing
# [Mon Jan 17 18:05:15 2022] 127.0.0.1:45376 Accepted
# [Mon Jan 17 18:05:16 2022] 127.0.0.1:45376 Closing
# [Mon Jan 17 18:05:16 2022] 127.0.0.1:45382 Accepted
# [Mon Jan 17 18:05:16 2022] 127.0.0.1:45382 Closing
# 2) FundraisersCept: Have fundraisers page
#  Test  tests_codeception/acceptance/FundraisersCept.php
#  Step  See current url equals "/fundraisers/create"
#  Fail  Failed asserting that two strings are identical.
# - Expected | + Actual
# @@ @@
# -'/fundraisers/create'
# +'/verify-email'
#
# Scenario Steps:
#
#  9. $I->seeCurrentUrlEquals("/fundraisers/create") at tests_codeception/acceptance/FundraisersCept.php:20
#  8. $I->click("Create new...") at tests_codeception/acceptance/FundraisersCept.php:19
#  7. $I->seeCurrentUrlEquals("/fundraisers") at tests_codeception/acceptance/FundraisersCept.php:17
#  6. $I->click("Fundraisers") at tests_codeception/acceptance/FundraisersCept.php:15
#  5. $I->seeCurrentUrlEquals("/dashboard") at tests_codeception/acceptance/FundraisersCept.php:14
#  4. $I->click("Log in") at tests_codeception/acceptance/FundraisersCept.php:12
#
# Artifacts:
#
# Html: /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project/tests_codeception/_output/FundraisersCept.fail.html
# Response: /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project/tests_codeception/_output/FundraisersCept.fail.html
#
# ---------
# 3) UserCept: Have users page
#  Test  tests_codeception/acceptance/UserCept.php
#  Step  Select option "Joe Doe","Log Out"
#  Fail  Form field by Label or CSS element with 'Joe Doe' was not found.
#
# Scenario Steps:
#
#  67. $I->selectOption("Joe Doe","Log Out") at tests_codeception/acceptance/UserCept.php:112
#  66. $I->dontSee("john.doe@gmail.com") at tests_codeception/acceptance/UserCept.php:110
#  65. $I->dontSee("John Doe") at tests_codeception/acceptance/UserCept.php:109
#  64. $I->see("joe.doeee@gmail.com") at tests_codeception/acceptance/UserCept.php:107
#  63. $I->see("Joe Doe") at tests_codeception/acceptance/UserCept.php:106
#  62. $I->seeCurrentUrlEquals("/dashboard") at tests_codeception/acceptance/UserCept.php:104
#
# Artifacts:
#
# Html: /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project/tests_codeception/_output/UserCept.fail.html
# Response: /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt/project/tests_codeception/_output/UserCept.fail.html
#
# FAILURES!
# Tests: 6, Assertions: 54, Failures: 3.

# %% [markdown]
# Edit the code:

# %% [markdown]
# You can test your solution using included tests:

# %%
! killall php php8.0

# %cd ..
# Out:
# /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/Projekt

# %%
! phpstorm project
# Out:
# (java:166): dbind-WARNING **: 18:05:39.553: Couldn't connect to accessibility bus: Failed to connect to socket /tmp/dbus-5ins2bBcbb: No such file or directory
# 2022-01-17 18:05:47,497 [   8610]   WARN - l.NotificationGroupManagerImpl - Notification group CodeWithMe is already registered (group=com.intellij.notification.NotificationGroup@5e13626). Plugin descriptor: PluginDescriptor(name=Code With Me, id=com.jetbrains.codeWithMe, descriptorPath=plugin.xml, path=/opt/PhpStorm-212.5080.71/plugins/cwm-plugin, version=212.5080.71, package=null)
# 2022-01-17 18:05:47,956 [   9069]  ERROR - nSystem.impl.ActionManagerImpl - Assertion failed
# java.lang.Throwable: Assertion failed
# 	at com.intellij.openapi.diagnostic.Logger.assertTrue(Logger.java:218)
# 	at com.intellij.openapi.diagnostic.Logger.assertTrue(Logger.java:227)
# 	at com.intellij.openapi.actionSystem.impl.ActionManagerImpl.<init>(ActionManagerImpl.java:139)
# 	at com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager.<init>(BackendActionManager.kt:14)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# 	at java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:62)
# 	at java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# 	at java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:490)
# 	at com.intellij.serviceContainer.ConstructorInjectionKt.instantiateUsingPicoContainer(constructorInjection.kt:47)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClassWithConstructorInjection(ComponentManagerImpl.kt:877)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.createAndInitialize(ServiceComponentAdapter.kt:48)
# 	at com.intellij.serviceContainer.ServiceComponentAdapter.doCreateInstance(ServiceComponentAdapter.kt:36)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstanceUncached(BaseComponentAdapter.kt:113)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance(BaseComponentAdapter.kt:67)
# 	at com.intellij.serviceContainer.BaseComponentAdapter.getInstance$default(BaseComponentAdapter.kt:60)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.doGetService(ComponentManagerImpl.kt:590)
# 	at com.intellij.serviceContainer.ComponentManagerImpl.getService(ComponentManagerImpl.kt:573)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getFromSelfOrCurrentSession(ClientAwareComponentManager.kt:37)
# 	at com.intellij.openapi.client.ClientAwareComponentManager.getService(ClientAwareComponentManager.kt:22)
# 	at com.intellij.openapi.actionSystem.ActionManager.getInstance(ActionManager.java:30)
# 	at com.intellij.ide.ui.customization.CustomActionsSchema.getCorrectedAction(CustomActionsSchema.java:289)
# 	at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension.runToolbarExists(NavBarRootPaneExtension.java:75)
# 	at com.intellij.ide.navigationToolbar.NavBarBorder.getBorderInsets(NavBarBorder.java:45)
# 	at java.desktop/javax.swing.JComponent.setBorder(JComponent.java:1815)
# 	at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension$3.updateUI(NavBarRootPaneExtension.java:234)
# 	at java.desktop/javax.swing.JPanel.<init>(JPanel.java:86)
# 	at java.desktop/javax.swing.JPanel.<init>(JPanel.java:95)
# 	at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension$3.<init>(NavBarRootPaneExtension.java:197)
# 	at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension.buildNavBarPanel(NavBarRootPaneExtension.java:197)
# 	at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension.addNavigationBarPanel(NavBarRootPaneExtension.java:106)
# 	at com.intellij.ide.navigationToolbar.NavBarRootPaneExtension.getComponent(NavBarRootPaneExtension.java:99)
# 	at com.intellij.openapi.wm.impl.IdeRootPane.installNorthComponents(IdeRootPane.java:329)
# 	at com.intellij.openapi.wm.impl.ProjectFrameHelper.setProject(ProjectFrameHelper.java:376)
# 	at com.intellij.openapi.wm.impl.WindowManagerImpl.assignFrame(WindowManagerImpl.kt:281)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$projectLoaded$1.run(ProjectFrameAllocator.kt:171)
# 	at com.intellij.openapi.application.TransactionGuardImpl.runWithWritingAllowed(TransactionGuardImpl.java:214)
# 	at com.intellij.openapi.application.TransactionGuardImpl.access$200(TransactionGuardImpl.java:21)
# 	at com.intellij.openapi.application.TransactionGuardImpl$2.run(TransactionGuardImpl.java:196)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:794)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.lambda$invokeLater$4(ApplicationImpl.java:350)
# 	at com.intellij.openapi.application.impl.FlushQueue.doRun(FlushQueue.java:84)
# 	at com.intellij.openapi.application.impl.FlushQueue.runNextEvent(FlushQueue.java:133)
# 	at com.intellij.openapi.application.impl.FlushQueue.flushNow(FlushQueue.java:46)
# 	at com.intellij.openapi.application.impl.FlushQueue$FlushNow.run(FlushQueue.java:189)
# 	at java.desktop/java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:313)
# 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:776)
# 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:727)
# 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:721)
# 	at java.base/java.security.AccessController.doPrivileged(Native Method)
# 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:85)
# 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:746)
# 	at com.intellij.ide.IdeEventQueue.defaultDispatchEvent(IdeEventQueue.java:887)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent(IdeEventQueue.java:756)
# 	at com.intellij.ide.IdeEventQueue.lambda$dispatchEvent$7(IdeEventQueue.java:443)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computePrioritized(CoreProgressManager.java:825)
# 	at com.intellij.ide.IdeEventQueue.lambda$dispatchEvent$8(IdeEventQueue.java:442)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:794)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.java:488)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:203)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:124)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:109)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:101)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:90)
# 2022-01-17 18:05:47,989 [   9102]  ERROR - nSystem.impl.ActionManagerImpl - PhpStorm 2021.2.1  Build #PS-212.5080.71
# 2022-01-17 18:05:47,990 [   9103]  ERROR - nSystem.impl.ActionManagerImpl - JDK: 11.0.11; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2022-01-17 18:05:47,990 [   9103]  ERROR - nSystem.impl.ActionManagerImpl - OS: Linux
# 2022-01-17 18:05:47,999 [   9112]  ERROR - nSystem.impl.ActionManagerImpl - Last Action:
# [JetBrains Runtime] Detected slow X11, switched off alpha compositing of images. Control with -Dremote.x11.workaround={true|false|auto}.
# 2022-01-17 18:06:01,953 [  23066]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 3727 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:01,996 [  23109]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:02,304 [  23417]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:02,344 [  23457]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:02,606 [  23719]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:02,630 [  23743]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:02,911 [  24024]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:02,938 [  24051]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:03,128 [  24241]  ERROR - terminal.emulator.JediEmulator - Unhandled Control sequence
# parsed                        :ESC[?2004h
# bytes read                    :ESC[
# 2022-01-17 18:06:03,250 [  24363]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:03,276 [  24389]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:03,480 [  24593]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:03,527 [  24640]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:03,730 [  24843]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:03,749 [  24862]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:04,044 [  25157]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:04,067 [  25180]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:04,261 [  25374]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:04,286 [  25399]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:04,396 [  25509]   WARN - com.intellij.util.xmlb.Binding - no accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType
# 2022-01-17 18:06:04,423 [  25536]   WARN - ctionSystem.impl.ActionUpdater - 1566 ms to expand group child CWMTelephonyGroup
# 2022-01-17 18:06:04,423 [  25536]   WARN - ctionSystem.impl.ActionUpdater - 1572 ms to expand group child CodeWithMeNavbarGroup
# 2022-01-17 18:06:04,470 [  25583]   WARN - pl.local.NativeFileWatcherImpl - table error: collision at 2 (new /home/student/To_Ten_Projekt/php_2021_przeprowadzanie_zbiorek_pienieznych_online/.env/home/cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178, existing /home/student/.cache/JetBrains/PhpStorm2021.2/javascript/typings/lodash/4.14.178)
# 2022-01-17 18:06:04,539 [  25652]   WARN - pl.local.NativeFileWatcherImpl - Watcher terminated with exit code 3
# 2022-01-17 18:06:04,539 [  25652]   WARN - api.vfs.impl.local.FileWatcher - File watcher failed repeatedly and has been disabled
# 2022-01-17 18:06:05,710 [  26823]   WARN - ctionSystem.impl.ActionUpdater - 1085 ms to expand group child TabList
# 2022-01-17 18:06:05,712 [  26825]   WARN - ctionSystem.impl.ActionUpdater - 1088 ms to expand group child TabList
# 2022-01-17 18:06:13,565 [  34678]   WARN - ctionSystem.impl.ActionUpdater - Slow (891 ms) `com.intellij.database.run.actions.ChangePageSizeActionGroup#update`. Consider speeding it up and/or implementing UpdateInBackground.
# 2022-01-17 18:06:13,568 [  34681]   WARN - ctionSystem.impl.ActionUpdater - 1135 ms to expand group child Console.TableResult.ChooseExtractor
# 2022-01-17 18:06:13,793 [  34906]   WARN - ctionSystem.impl.ActionUpdater - 1361 ms to expand group child Console.TableResult.NavigationAndEditing.Group
# 2022-01-17 18:06:51,125 [  72238]  ERROR - terminal.emulator.JediEmulator - Unhandled Control sequence
# parsed                        :ESC[?2004l
# bytes read                    :ESC[
# 2022-01-17 18:07:07,085 [  88198]   WARN - ctionSystem.impl.ActionUpdater - 1230 ms to expand group child TabList
# 2022-01-17 18:07:07,085 [  88198]   WARN - ctionSystem.impl.ActionUpdater - 1230 ms to expand group child TabList
# 2022-01-17 18:07:08,677 [  89790]   WARN - ctionSystem.impl.ActionUpdater - 1023 ms to expand group child null
# 2022-01-17 18:07:08,678 [  89791]   WARN - ctionSystem.impl.ActionUpdater - 1025 ms to expand group child null

# %% [markdown]
# Stop database:

# %%
! sudo docker container stop mysql
# Out:
# mysql
